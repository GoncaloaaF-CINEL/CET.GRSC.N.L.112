# %%
import random
lst = [1]
my_set = {1}

# %%
for i in range(1_000):
    num = random.randint(1, 1000000000)
    my_set.add(num)

lst = list(my_set)

# %%
lst.__len__(), my_set.__len__()
# Out:
# (1001, 1001)

# %%
resp = []
for num in lst:
    if num % 2 == 0:
        resp.append(num)

# %%
resp2 = [num for num in lst if num % 2 == 0]

# %%
for i in range(10000):
    3123 in lst

# %%
for i in range(10000):
    3123 in my_set
